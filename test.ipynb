# %%
import jwt

token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyX2lkIjoiYzM5NTM3NzUtMDQ4ZS00ZjUzLTkzMWEtMTlmNzViYTlmODAwIiwidXNlcl9uYW1lIjoidml0aW1pbkMiLCJlbWFpbCI6Imtpa2lwaGFtMTA4QGdtYWlsLmNvbSIsInJvbGUiOiJ1c2VyIiwiZXhwIjoxNzQ2NTU1MTQ4fQ.jUotJf4Sdl6QYs1IpEae5rOYjYJuAVRlIamwyA4zRSM"

# Decode mà không kiểm tra chữ ký
decoded = jwt.decode(token, options={"verify_signature": False})
print(decoded)
# Out:
# {'user_id': 'c3953775-048e-4f53-931a-19f75ba9f800', 'user_name': 'vitiminC', 'email': 'kikipham108@gmail.com', 'role': 'user', 'exp': 1746555148}
